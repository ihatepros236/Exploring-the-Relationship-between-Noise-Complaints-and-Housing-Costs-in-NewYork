# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %% [markdown]
# # Zillow home value index

# %%
zillow_index_sales = pd.read_csv('Zip_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv')
zillow_index_sales.head()
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     91940         0       77449        zip        TX    TX       NaN
# 1     91982         1       77494        zip        TX    TX       NaN
# 2     93144         2       79936        zip        TX    TX   El Paso
# 3     62080         3       11368        zip        NY    NY  New York
# 4     62093         4       11385        zip        NY    NY  New York
#
#                                    Metro        CountyName     2000-01-31  \
# 0   Houston-The Woodlands-Sugar Land, TX     Harris County  111025.364504
# 1   Houston-The Woodlands-Sugar Land, TX  Fort Bend County  217709.460879
# 2                            El Paso, TX    El Paso County   93297.846024
# 3  New York-Newark-Jersey City, NY-NJ-PA     Queens County   75454.474440
# 4  New York-Newark-Jersey City, NY-NJ-PA     Queens County  237548.770794
#
#    ...     2022-04-30     2022-05-31     2022-06-30     2022-07-31  \
# ...

# %%
zip_codes_with_complaints = pd.read_csv('zip_codes.csv')
zip_codes_with_complaints.head()
# Out:
#    incident_zip  unique_key
# 0             0           1
# 1            83         341
# 2         10000        1149
# 3         10001       35979
# 4         10002       79142

# %%
columns_zillow = list(zillow_index_sales.columns)
list_zips_311 = list(zip_codes_with_complaints['incident_zip'])
filter_zillow_sales = zillow_index_sales[zillow_index_sales['RegionName'].isin(list_zips_311)]
zillow_melt_sales = pd.melt(filter_zillow_sales, id_vars='RegionName', value_vars=[x for x in columns_zillow if ('201' in x or '202' in x) ])\
            .sort_values(by=['RegionName','variable'])\
            .rename(columns = {'variable':'month'})
zillow_melt_sales['zillow_month'] =  pd.DatetimeIndex(zillow_melt_sales['month']).year.astype('str') + '-' +pd.DatetimeIndex(zillow_melt_sales['month']).month.astype('str').str.zfill(2)
#zillow_melt_sales.drop(columns=('month'), inplace = True)
zillow_melt_sales.rename(columns={'value':'zillow_sales_value_index','month': 'zillow_month_day','RegionName':'zillow_zip'},inplace = True)
zillow_melt_sales.head()
# Out:
#      zillow_zip zillow_month_day  zillow_sales_value_index zillow_month
# 139       10001       2010-01-31             613892.359651      2010-01
# 317       10001       2010-02-28             607612.163912      2010-02
# 495       10001       2010-03-31             604503.832397      2010-03
# 673       10001       2010-04-30             605535.608025      2010-04
# 851       10001       2010-05-31             608584.460474      2010-05

# %%
zillow_melt_sales.to_csv('zillow_sales_value_index_zip_month.csv')

# %% [markdown]
# # Zillow rent index

# %%
zillow_index_rent = pd.read_csv('Zip_zori_sm_month_cleaned.csv')
zillow_index_rent.head()
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0   62093.0       4.0       11385        zip        NY    NY  New York
# 1   62046.0      11.0       11236        zip        NY    NY  New York
# 2   62019.0      14.0       11208        zip        NY    NY  New York
# 3   61807.0      15.0       10467        zip        NY    NY  New York
# 4   62037.0      16.0       11226        zip        NY    NY  New York
#
#                                    Metro     CountyName    3/31/2015  ...  \
# 0  New York-Newark-Jersey City, NY-NJ-PA  Queens County  2155.301037  ...
# 1  New York-Newark-Jersey City, NY-NJ-PA   Kings County  1760.906084  ...
# 2  New York-Newark-Jersey City, NY-NJ-PA   Kings County  1697.735551  ...
# 3  New York-Newark-Jersey City, NY-NJ-PA   Bronx County  1383.923519  ...
# 4  New York-Newark-Jersey City, NY-NJ-PA   Kings County  1983.451860  ...
#
#      4/30/2022    5/31/2022    6/30/2022    7/31/2022    8/31/2022  \
# ...

# %%
columns_zillow = list(zillow_index_rent.columns)
list_zips_311 = list(zip_codes_with_complaints['incident_zip'])
filter_zillow_rent = zillow_index_rent[zillow_index_rent['RegionName'].isin(list_zips_311)]
zillow_melt_rent = pd.melt(filter_zillow_rent, id_vars='RegionName', value_vars=[x for x in columns_zillow if ('201' in x or '202' in x) ])\
            .sort_values(by=['RegionName','variable'])\
            .rename(columns = {'variable':'month'})
zillow_melt_rent['zillow_month'] =  pd.DatetimeIndex(zillow_melt_rent['month']).year.astype('str') + '-' +pd.DatetimeIndex(zillow_melt_rent['month']).month.astype('str').str.zfill(2)
#zillow_melt_rent.drop(columns=('month'), inplace = True)
zillow_melt_rent.rename(columns={'value':'zillow_rent_value_index','month': 'zillow_month_day','RegionName':'zillow_zip'},inplace = True)
zillow_melt_rent.head()
# Out:
#        zillow_zip zillow_month_day zillow_rent_value_index zillow_month
# 2141        10000        1/31/2016                  2833.6      2016-01
# 4541        10000        1/31/2017                  2820.8      2017-01
# 6941        10000        1/31/2018                  2859.2      2018-01
# 9341        10000        1/31/2019                    2927      2019-01
# 11741       10000        1/31/2020                  3016.4      2020-01

# %%
zillow_melt_rent.to_csv('zillow_rent_value_index_zip_month_cleaned.csv')
